# %%
# %sql
CREATE VOLUME dev_catalog.bronze.bronze_volume;                   --Managed Volume

# %%
# %sql
CREATE EXTERNAL VOLUME dev_catalog.bronze.bronze_external_volume  --External Volume
LOCATION 'abfss://bronze@<EMAIL>.dfs.core.windows.net/'

# %%
#SELECT * FROM csv.`/Volumes/dev_catalog/bronze/bronze_volume/fact_sales.csv`
df = spark.read.csv("/Volumes/dev_catalog/bronze/bronze_volume/fact_sales.csv", header=True, inferSchema=True)
display(df)

# %% [markdown]
# ###DBUtils

# %%
dbutils.fs.ls("/Volumes/dev_catalog/bronze/bronze_volume")

# %%
dbutils.fs.mkdirs("/Volumes/dev_catalog/bronze/bronze_volume/sales")

# %%
dbutils.fs.cp("/Volumes/dev_catalog/bronze/bronze_volume/fact_sales.csv","/Volumes/dev_catalog/bronze/bronze_volume/customer/")

# %%
dbutils.fs.rm("/Volumes/dev_catalog/bronze/bronze_volume/fact_sales.csv")

# %%
dbutils.fs.put("/Volumes/dev_catalog/bronze/bronze_volume/sales/test.txt", "Hello Databricks", True)

# %%
lst = dbutils.fs.ls("/Volumes/dev_catalog/bronze/bronze_volume/sales/")
for i in lst:
    print(i.name)
    print(i.path)
    dbutils.fs.rm(f"/Volumes/dev_catalog/bronze/bronze_volume/sales/{i.name}")

# %%
dbutils.widgets.text("ValDate","")
AsofDate = dbutils.widgets.get("ValDate")
print(AsofDate)
